# %%
from keras.utils import to_categorical
from keras.preprocessing.image import load_img
from keras.models import Sequential
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dropout, Dense, BatchNormalization, GlobalAveragePooling2D, Flatten
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
import os
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
from tensorflow.keras.preprocessing import image
from sklearn.preprocessing import LabelEncoder

# %%
TRAIN_DIR = 'C:\\Users\\praty\\Documents\\GitHub\\FaceEx\\Data\\train'
TEST_DIR = 'C:\\Users\\praty\\Documents\\GitHub\\FaceEx\\Data\\test'

# %%
def createdataframe(dir):
    image_paths = []
    labels = []
    for label in os.listdir(dir):
        for imagename in os.listdir(os.path.join(dir,label)):
            image_paths.append(os.path.join(dir,label,imagename))
            labels.append(label)
        print(label, "completed")
    return image_paths,labels

# %%
train = pd.DataFrame()
train['image'], train['label'] = createdataframe(TRAIN_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(train)
# Out:
#                                                    image     label
# 0      C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...     angry
# 1      C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...     angry
# 2      C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...     angry
# 3      C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...     angry
# 4      C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...     angry
# ...                                                  ...       ...
# 28816  C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...  surprise
# 28817  C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...  surprise
# 28818  C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...  surprise
# 28819  C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...  surprise
# 28820  C:\Users\praty\Documents\GitHub\FaceEx\Data\tr...  surprise
#
# [28821 rows x 2 columns]

# %%
test = pd.DataFrame()
test['image'], test['label'] = createdataframe(TEST_DIR)
# Out:
# angry completed
# disgust completed
# fear completed
# happy completed
# neutral completed
# sad completed
# surprise completed

# %%
print(test)
# Out:
#                                                   image     label
# 0     C:\Users\praty\Documents\GitHub\FaceEx\Data\te...     angry
# 1     C:\Users\praty\Documents\GitHub\FaceEx\Data\te...     angry
# 2     C:\Users\praty\Documents\GitHub\FaceEx\Data\te...     angry
# 3     C:\Users\praty\Documents\GitHub\FaceEx\Data\te...     angry
# 4     C:\Users\praty\Documents\GitHub\FaceEx\Data\te...     angry
# ...                                                 ...       ...
# 7061  C:\Users\praty\Documents\GitHub\FaceEx\Data\te...  surprise
# 7062  C:\Users\praty\Documents\GitHub\FaceEx\Data\te...  surprise
# 7063  C:\Users\praty\Documents\GitHub\FaceEx\Data\te...  surprise
# 7064  C:\Users\praty\Documents\GitHub\FaceEx\Data\te...  surprise
# 7065  C:\Users\praty\Documents\GitHub\FaceEx\Data\te...  surprise
#
# [7066 rows x 2 columns]

# %%
def extract_features(images):
    features = []
    for image in tqdm(images):
        img = load_img(image, color_mode="grayscale")
        img = np.array(img)
        features.append(img)
    features = np.array(features)
    features = features.reshape(len(features),48,48,1)
    return features

# %%
train_features = extract_features(train['image'])
# Out:
#   0%|          | 0/28821 [00:00<?, ?it/s]

# %%
test_features = extract_features(test['image'])
# Out:
#   0%|          | 0/7066 [00:00<?, ?it/s]

# %%
x_train = train_features/255.0
x_test = test_features/255.0

# %%
le = LabelEncoder()
le.fit(train['label'])
# Out:
# LabelEncoder()

# %%
y_train = le.transform(train['label'])
y_test = le.transform(test['label'])

# %%
y_train = to_categorical(y_train,num_classes = 7)
y_test = to_categorical(y_test,num_classes = 7)

# %%
# Build the model
model = Sequential()

# Convolutional layers with BatchNormalization and Dropout
model.add(Conv2D(128, kernel_size=(3,3), activation='relu', input_shape=(48,48,1)))
model.add(BatchNormalization())  # Normalizing the output of the conv layer
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(256, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())  # Add BatchNormalization here as well
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(Conv2D(512, kernel_size=(3,3), activation='relu'))
model.add(BatchNormalization())
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.4))

model.add(GlobalAveragePooling2D())

# Flatten for fully connected layers
model.add(Flatten())

# Fully connected layers
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.4))

model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))

# Output layer for 7 classes (assuming softmax for multi-class classification)
model.add(Dense(7, activation='softmax'))
# Out:
# c:\Users\praty\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
# Callbacks
early_stopping = EarlyStopping(monitor='accuracy', patience=10, restore_best_weights=True)
lr_scheduler = ReduceLROnPlateau(monitor='accuracy', factor=0.5, patience=5)

# %%
model.fit(x= x_train, y = y_train, batch_size = 64, epochs = 75, validation_data = (x_test,y_test), callbacks=[early_stopping, lr_scheduler])
# Out:
# Epoch 1/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 372s 817ms/step - accuracy: 0.2115 - loss: 2.0552 - val_accuracy: 0.2583 - val_loss: 1.8207 - learning_rate: 0.0010
# Epoch 2/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 373s 826ms/step - accuracy: 0.3187 - loss: 1.6816 - val_accuracy: 0.3709 - val_loss: 1.5818 - learning_rate: 0.0010
# Epoch 3/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 407s 901ms/step - accuracy: 0.4169 - loss: 1.5027 - val_accuracy: 0.3063 - val_loss: 1.7206 - learning_rate: 0.0010
# Epoch 4/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 386s 856ms/step - accuracy: 0.4608 - loss: 1.4031 - val_accuracy: 0.4843 - val_loss: 1.3648 - learning_rate: 0.0010
# Epoch 5/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 348s 771ms/step - accuracy: 0.4878 - loss: 1.3377 - val_accuracy: 0.5204 - val_loss: 1.2790 - learning_rate: 0.0010
# Epoch 6/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 313s 694ms/step - accuracy: 0.5193 - loss: 1.2709 - val_accuracy: 0.5091 - val_loss: 1.3255 - learning_rate: 0.0010
# Epoch 7/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 348s 772ms/step - accuracy: 0.5315 - loss: 1.2375 - val_accuracy: 0.5501 - val_loss: 1.2044 - learning_rate: 0.0010
# Epoch 8/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 363s 804ms/step - accuracy: 0.5440 - loss: 1.1971 - val_accuracy: 0.5432 - val_loss: 1.2093 - learning_rate: 0.0010
# Epoch 9/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 361s 801ms/step - accuracy: 0.5619 - loss: 1.1515 - val_accuracy: 0.5352 - val_loss: 1.2273 - learning_rate: 0.0010
# Epoch 10/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 357s 791ms/step - accuracy: 0.5718 - loss: 1.1339 - val_accuracy: 0.5132 - val_loss: 1.2576 - learning_rate: 0.0010
# Epoch 11/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 323s 715ms/step - accuracy: 0.5811 - loss: 1.1046 - val_accuracy: 0.5770 - val_loss: 1.1136 - learning_rate: 0.0010
# Epoch 12/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 324s 719ms/step - accuracy: 0.5959 - loss: 1.0751 - val_accuracy: 0.5265 - val_loss: 1.2333 - learning_rate: 0.0010
# Epoch 13/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 324s 719ms/step - accuracy: 0.5983 - loss: 1.0584 - val_accuracy: 0.5526 - val_loss: 1.1922 - learning_rate: 0.0010
# Epoch 14/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 322s 714ms/step - accuracy: 0.6064 - loss: 1.0390 - val_accuracy: 0.5825 - val_loss: 1.1267 - learning_rate: 0.0010
# Epoch 15/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 319s 707ms/step - accuracy: 0.6233 - loss: 0.9978 - val_accuracy: 0.5977 - val_loss: 1.0989 - learning_rate: 0.0010
# Epoch 16/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 318s 705ms/step - accuracy: 0.6315 - loss: 0.9936 - val_accuracy: 0.5972 - val_loss: 1.1005 - learning_rate: 0.0010
# Epoch 17/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 318s 705ms/step - accuracy: 0.6427 - loss: 0.9626 - val_accuracy: 0.5824 - val_loss: 1.1279 - learning_rate: 0.0010
# Epoch 18/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 319s 707ms/step - accuracy: 0.6490 - loss: 0.9359 - val_accuracy: 0.6139 - val_loss: 1.0602 - learning_rate: 0.0010
# Epoch 19/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 319s 706ms/step - accuracy: 0.6537 - loss: 0.9280 - val_accuracy: 0.5443 - val_loss: 1.2651 - learning_rate: 0.0010
# Epoch 20/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 319s 706ms/step - accuracy: 0.6686 - loss: 0.8854 - val_accuracy: 0.5696 - val_loss: 1.2339 - learning_rate: 0.0010
# Epoch 21/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 318s 705ms/step - accuracy: 0.6732 - loss: 0.8828 - val_accuracy: 0.5822 - val_loss: 1.1630 - learning_rate: 0.0010
# Epoch 22/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 318s 705ms/step - accuracy: 0.6803 - loss: 0.8523 - val_accuracy: 0.5981 - val_loss: 1.1318 - learning_rate: 0.0010
# Epoch 23/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 337s 748ms/step - accuracy: 0.6892 - loss: 0.8356 - val_accuracy: 0.6159 - val_loss: 1.0786 - learning_rate: 0.0010
# Epoch 24/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 377s 837ms/step - accuracy: 0.6933 - loss: 0.8187 - val_accuracy: 0.6098 - val_loss: 1.1332 - learning_rate: 0.0010
# Epoch 25/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 326s 723ms/step - accuracy: 0.7070 - loss: 0.7955 - val_accuracy: 0.6302 - val_loss: 1.0860 - learning_rate: 0.0010
# Epoch 26/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 365s 809ms/step - accuracy: 0.7114 - loss: 0.7897 - val_accuracy: 0.6177 - val_loss: 1.0916 - learning_rate: 0.0010
# Epoch 27/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 390s 864ms/step - accuracy: 0.7185 - loss: 0.7654 - val_accuracy: 0.5232 - val_loss: 1.3868 - learning_rate: 0.0010
# Epoch 28/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 372s 825ms/step - accuracy: 0.7160 - loss: 0.7629 - val_accuracy: 0.6356 - val_loss: 1.0536 - learning_rate: 0.0010
# Epoch 29/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 396s 879ms/step - accuracy: 0.7263 - loss: 0.7448 - val_accuracy: 0.6240 - val_loss: 1.1270 - learning_rate: 0.0010
# Epoch 30/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 391s 867ms/step - accuracy: 0.7343 - loss: 0.7153 - val_accuracy: 0.6216 - val_loss: 1.1425 - learning_rate: 0.0010
# Epoch 31/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 326s 722ms/step - accuracy: 0.7414 - loss: 0.7041 - val_accuracy: 0.6335 - val_loss: 1.0996 - learning_rate: 0.0010
# Epoch 32/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 337s 747ms/step - accuracy: 0.7442 - loss: 0.6842 - val_accuracy: 0.5872 - val_loss: 1.2791 - learning_rate: 0.0010
# Epoch 33/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 357s 791ms/step - accuracy: 0.7512 - loss: 0.6771 - val_accuracy: 0.6394 - val_loss: 1.1260 - learning_rate: 0.0010
# Epoch 34/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 369s 818ms/step - accuracy: 0.7564 - loss: 0.6727 - val_accuracy: 0.6172 - val_loss: 1.1453 - learning_rate: 0.0010
# Epoch 35/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 368s 817ms/step - accuracy: 0.7606 - loss: 0.6549 - val_accuracy: 0.6349 - val_loss: 1.1170 - learning_rate: 0.0010
# Epoch 36/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 368s 816ms/step - accuracy: 0.7661 - loss: 0.6407 - val_accuracy: 0.6434 - val_loss: 1.1140 - learning_rate: 0.0010
# Epoch 37/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 369s 818ms/step - accuracy: 0.7675 - loss: 0.6348 - val_accuracy: 0.6335 - val_loss: 1.1661 - learning_rate: 0.0010
# Epoch 38/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 369s 818ms/step - accuracy: 0.7821 - loss: 0.5998 - val_accuracy: 0.6054 - val_loss: 1.2835 - learning_rate: 0.0010
# Epoch 39/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 381s 844ms/step - accuracy: 0.7836 - loss: 0.5913 - val_accuracy: 0.6356 - val_loss: 1.1764 - learning_rate: 0.0010
# Epoch 40/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 402s 892ms/step - accuracy: 0.7882 - loss: 0.5847 - val_accuracy: 0.6151 - val_loss: 1.2210 - learning_rate: 0.0010
# Epoch 41/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 404s 897ms/step - accuracy: 0.7890 - loss: 0.5760 - val_accuracy: 0.6364 - val_loss: 1.2491 - learning_rate: 0.0010
# Epoch 42/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 6723s 15s/step - accuracy: 0.7969 - loss: 0.5621 - val_accuracy: 0.6294 - val_loss: 1.2307 - learning_rate: 0.0010
# Epoch 43/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 465s 1s/step - accuracy: 0.8026 - loss: 0.5576 - val_accuracy: 0.6414 - val_loss: 1.2005 - learning_rate: 0.0010
# Epoch 44/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 513s 1s/step - accuracy: 0.8041 - loss: 0.5434 - val_accuracy: 0.6254 - val_loss: 1.2859 - learning_rate: 0.0010
# Epoch 45/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 473s 1s/step - accuracy: 0.8096 - loss: 0.5332 - val_accuracy: 0.6415 - val_loss: 1.2332 - learning_rate: 0.0010
# Epoch 46/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 362s 803ms/step - accuracy: 0.8141 - loss: 0.5250 - val_accuracy: 0.6465 - val_loss: 1.2435 - learning_rate: 0.0010
# Epoch 47/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 343s 762ms/step - accuracy: 0.8167 - loss: 0.5193 - val_accuracy: 0.6408 - val_loss: 1.2410 - learning_rate: 0.0010
# Epoch 48/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 332s 737ms/step - accuracy: 0.8191 - loss: 0.5075 - val_accuracy: 0.6357 - val_loss: 1.2256 - learning_rate: 0.0010
# Epoch 49/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 333s 739ms/step - accuracy: 0.8160 - loss: 0.5037 - val_accuracy: 0.6378 - val_loss: 1.2829 - learning_rate: 0.0010
# Epoch 50/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 376s 834ms/step - accuracy: 0.8230 - loss: 0.5026 - val_accuracy: 0.6363 - val_loss: 1.3126 - learning_rate: 0.0010
# Epoch 51/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 420s 932ms/step - accuracy: 0.8268 - loss: 0.4944 - val_accuracy: 0.6294 - val_loss: 1.3387 - learning_rate: 0.0010
# Epoch 52/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 419s 928ms/step - accuracy: 0.8313 - loss: 0.4807 - val_accuracy: 0.6462 - val_loss: 1.2424 - learning_rate: 0.0010
# Epoch 53/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 397s 881ms/step - accuracy: 0.8372 - loss: 0.4650 - val_accuracy: 0.6507 - val_loss: 1.2450 - learning_rate: 0.0010
# Epoch 54/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 394s 873ms/step - accuracy: 0.8309 - loss: 0.4733 - val_accuracy: 0.5918 - val_loss: 1.6020 - learning_rate: 0.0010
# Epoch 55/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 376s 834ms/step - accuracy: 0.8341 - loss: 0.4677 - val_accuracy: 0.6380 - val_loss: 1.2784 - learning_rate: 0.0010
# Epoch 56/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 373s 827ms/step - accuracy: 0.8453 - loss: 0.4438 - val_accuracy: 0.6468 - val_loss: 1.2556 - learning_rate: 0.0010
# Epoch 57/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 372s 824ms/step - accuracy: 0.8408 - loss: 0.4478 - val_accuracy: 0.6142 - val_loss: 1.3795 - learning_rate: 0.0010
# Epoch 58/75
# 451/451 ━━━━━━━━━━━━━━━━━━━━ 0s 786ms/step - accuracy: 0.8454 - loss: 0.4363
